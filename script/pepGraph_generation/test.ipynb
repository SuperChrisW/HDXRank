# %%
import torch
import os
import accelerate
from accelerate import Accelerator
from pepGraph_BiLSTM import GNN_v2

# %%
import torch

graph_ensemble = torch.load('/home/lwang/models/HDX_LSTM/data/COVID_SPIKE/graph_ensemble/v1_ensemble/Wuhan_spike.pt')
print(graph_ensemble)
# Out:
# [[Data(x=[16, 48], edge_index=[2, 188], edge_attr=[188], seq_embedding=[30, 48], label='A_19_31', y=0.46690202999999997), Data(x=[16, 48], edge_index=[2, 188], edge_attr=[188], seq_embedding=[30, 48], label='A_32_42', y=0.12175535), Data(x=[16, 48], edge_index=[2, 188], edge_attr=[188], seq_embedding=[30, 48], label='A_32_43', y=0.17521851000000002), Data(x=[18, 48], edge_index=[2, 208], edge_attr=[208], seq_embedding=[30, 48], label='A_32_46', y=0.35550268), Data(x=[14, 48], edge_index=[2, 134], edge_attr=[134], seq_embedding=[30, 48], label='A_36_48', y=0.25979114), Data(x=[12, 48], edge_index=[2, 110], edge_attr=[110], seq_embedding=[30, 48], label='A_44_54', y=0.14537543), Data(x=[15, 48], edge_index=[2, 149], edge_attr=[149], seq_embedding=[30, 48], label='A_49_54', y=0.13457341), Data(x=[20, 48], edge_index=[2, 240], edge_attr=[240], seq_embedding=[30, 48], label='A_49_56', y=0.07607343), Data(x=[24, 48], edge_index=[2, 292], edge_attr=[292], seq_embedding=[30, 48], label='A_92
# ...
